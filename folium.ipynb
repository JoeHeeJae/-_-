# %%
pip install folium
# Out:
# Collecting folium
#   Downloading folium-0.14.0-py2.py3-none-any.whl (102 kB)
#      ---------------------------------------- 0.0/102.3 kB ? eta -:--:--
#      ---- ----------------------------------- 10.2/102.3 kB ? eta -:--:--
#      -------------- ---------------------- 41.0/102.3 kB 495.5 kB/s eta 0:00:01
#      ------------------------------------ 102.3/102.3 kB 844.4 kB/s eta 0:00:00
# Collecting branca>=0.6.0 (from folium)
#   Downloading branca-0.6.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: jinja2>=2.9 in c:\users\whgml\miniconda3\envs\gpu\lib\site-packages (from folium) (3.1.2)
# Requirement already satisfied: numpy in c:\users\whgml\miniconda3\envs\gpu\lib\site-packages (from folium) (1.25.2)
# Requirement already satisfied: requests in c:\users\whgml\miniconda3\envs\gpu\lib\site-packages (from folium) (2.31.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\whgml\miniconda3\envs\gpu\lib\site-packages (from jinja2>=2.9->folium) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\whgml\miniconda3\envs\gpu\lib\site-packages (from requests->folium) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\whgml\miniconda3\envs\gpu\lib\site-packages (from requests->folium) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\whgml\miniconda3\envs\gpu\lib\site-packages (from requests->folium) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\whgml\miniconda3\envs\gpu\lib\site-packages (from requests->folium) (2023.7.22)
# Installing collected packages: branca, folium
# Successfully installed branca-0.6.0 folium-0.14.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import folium

# %% [markdown]
# location에 위도, 경도 정보를 입력하여 입력한 위,경도 좌표를 기준으로 지도를 그릴 수 있습니다.
#
# 이때 zoom_start 정보를 지정하여 확대의 정도를 지정할 수 있습니다.
#
# 참고: zoom_start의 범위는 최대 18 입니다.

# %%
# 위도
latitude = 37.394946
# 경도
longitude = 127.111104

# %% [markdown]
# - location: 마커를 추가할 위도/경도 좌표를 입력 후
#
# - popup: 표기할 팝업 문구 지정 (마우스 클릭시 표기되는 문구)
#
# - tooltip: 표기할 툴팁 지정 (마우스 오버시 표기되는 문구)
#
# - 마커를 생성 후 기존에 생성된 지도 m에 추가합니다.

# %%
m = folium.Map(location=[latitude, longitude],
               zoom_start=17, 
               width=750, 
               height=500
              )
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8ca8897fb94e2e302617c1e1c82b4a4a {
#                     position: relative;
#                     width: 750.0px;
#                     height: 500.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8ca8897fb94e2e302617c1e1c82b4a4a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8ca8897fb94e2e302617c1e1c82b4a4a = L.map(
#                 &quot;map_8ca8897fb94e2e302617c1e1c82b4a4a&quot;,
#                 {
#                     center: [37.394946, 127.111104],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 17,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_390528d348d12aea5a88969cf4ed2ec4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8ca8897fb94e2e302617c1e1c82b4a4a);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
folium.Marker([latitude, longitude],
              popup="판교역",
              tooltip="판교역 입구").add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8ca8897fb94e2e302617c1e1c82b4a4a {
#                     position: relative;
#                     width: 750.0px;
#                     height: 500.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8ca8897fb94e2e302617c1e1c82b4a4a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8ca8897fb94e2e302617c1e1c82b4a4a = L.map(
#                 &quot;map_8ca8897fb94e2e302617c1e1c82b4a4a&quot;,
#                 {
#                     center: [37.394946, 127.111104],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 17,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_390528d348d12aea5a88969cf4ed2ec4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8ca8897fb94e2e302617c1e1c82b4a4a);
#
#
#             var marker_677b6d714d85d2699234e815741b250e = L.marker(
#                 [37.394946, 127.111104],
#                 {}
#             ).addTo(map_8ca8897fb94e2e302617c1e1c82b4a4a);
#
#
#         var popup_a5eab5f2c933018ce77ae90ec33257e8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a4d7f24dd0edadd9cd6218a738ad164f = $(`&lt;div id=&quot;html_a4d7f24dd0edadd9cd6218a738ad164f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;판교역&lt;/div&gt;`)[0];
#                 popup_a5eab5f2c933018ce77ae90ec33257e8.setContent(html_a4d7f24dd0edadd9cd6218a738ad164f);
#
#
#
#         marker_677b6d714d85d2699234e815741b250e.bindPopup(popup_a5eab5f2c933018ce77ae90ec33257e8)
#         ;
#
#
#
#
#             marker_677b6d714d85d2699234e815741b250e.bindTooltip(
#                 `&lt;div&gt;
#                      판교역 입구
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# 마커에 대한 스타일 변경도 가능합니다. 스타일 변경시 icon 파라미터에 folium.Icon(color=?, icon=?)을 지정합니다.

# %%
folium.Marker([latitude, longitude],
              popup="판교역",
              tooltip="판교역 입구", 
              icon=folium.Icon('red', icon='star'),
             ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8ca8897fb94e2e302617c1e1c82b4a4a {
#                     position: relative;
#                     width: 750.0px;
#                     height: 500.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8ca8897fb94e2e302617c1e1c82b4a4a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8ca8897fb94e2e302617c1e1c82b4a4a = L.map(
#                 &quot;map_8ca8897fb94e2e302617c1e1c82b4a4a&quot;,
#                 {
#                     center: [37.394946, 127.111104],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 17,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_390528d348d12aea5a88969cf4ed2ec4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8ca8897fb94e2e302617c1e1c82b4a4a);
#
#
#             var marker_677b6d714d85d2699234e815741b250e = L.marker(
#                 [37.394946, 127.111104],
#                 {}
#             ).addTo(map_8ca8897fb94e2e302617c1e1c82b4a4a);
#
#
#         var popup_a5eab5f2c933018ce77ae90ec33257e8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a4d7f24dd0edadd9cd6218a738ad164f = $(`&lt;div id=&quot;html_a4d7f24dd0edadd9cd6218a738ad164f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;판교역&lt;/div&gt;`)[0];
#                 popup_a5eab5f2c933018ce77ae90ec33257e8.setContent(html_a4d7f24dd0edadd9cd6218a738ad164f);
#
#
#
#         marker_677b6d714d85d2699234e815741b250e.bindPopup(popup_a5eab5f2c933018ce77ae90ec33257e8)
#         ;
#
#
#
#
#             marker_677b6d714d85d2699234e815741b250e.bindTooltip(
#                 `&lt;div&gt;
#                      판교역 입구
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_567e20637dc94dda4978568b6e91514e = L.marker(
#                 [37.394946, 127.111104],
#                 {}
#             ).addTo(map_8ca8897fb94e2e302617c1e1c82b4a4a);
#
#
#             var icon_acf09bcdcff2dbe261d5ddc9d4059b14 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_567e20637dc94dda4978568b6e91514e.setIcon(icon_acf09bcdcff2dbe261d5ddc9d4059b14);
#
#
#         var popup_5b1d9538c61b50285dfa55e2593d2f21 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_898367e047ba880a0a241845492e35b1 = $(`&lt;div id=&quot;html_898367e047ba880a0a241845492e35b1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;판교역&lt;/div&gt;`)[0];
#                 popup_5b1d9538c61b50285dfa55e2593d2f21.setContent(html_898367e047ba880a0a241845492e35b1);
#
#
#
#         marker_567e20637dc94dda4978568b6e91514e.bindPopup(popup_5b1d9538c61b50285dfa55e2593d2f21)
#         ;
#
#
#
#
#             marker_567e20637dc94dda4978568b6e91514e.bindTooltip(
#                 `&lt;div&gt;
#                      판교역 입구
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# popup이나 tooltip에 다음과 같이 html 코드를 삽입하여 이미지를 표기하거나 심지어 YouTube 영상도 삽입할 수 있습니다.

# %%
folium.Marker([latitude, longitude],
              popup='<iframe width="560" height="315" src="https://www.youtube.com/embed/dpwTOQri42s" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>',
              tooltip="판교역 입구").add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8ca8897fb94e2e302617c1e1c82b4a4a {
#                     position: relative;
#                     width: 750.0px;
#                     height: 500.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8ca8897fb94e2e302617c1e1c82b4a4a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8ca8897fb94e2e302617c1e1c82b4a4a = L.map(
#                 &quot;map_8ca8897fb94e2e302617c1e1c82b4a4a&quot;,
#                 {
#                     center: [37.394946, 127.111104],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 17,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_390528d348d12aea5a88969cf4ed2ec4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8ca8897fb94e2e302617c1e1c82b4a4a);
#
#
#             var marker_677b6d714d85d2699234e815741b250e = L.marker(
#                 [37.394946, 127.111104],
#                 {}
#             ).addTo(map_8ca8897fb94e2e302617c1e1c82b4a4a);
#
#
#         var popup_a5eab5f2c933018ce77ae90ec33257e8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a4d7f24dd0edadd9cd6218a738ad164f = $(`&lt;div id=&quot;html_a4d7f24dd0edadd9cd6218a738ad164f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;판교역&lt;/div&gt;`)[0];
#                 popup_a5eab5f2c933018ce77ae90ec33257e8.setContent(html_a4d7f24dd0edadd9cd6218a738ad164f);
#
#
#
#         marker_677b6d714d85d2699234e815741b250e.bindPopup(popup_a5eab5f2c933018ce77ae90ec33257e8)
#         ;
#
#
#
#
#             marker_677b6d714d85d2699234e815741b250e.bindTooltip(
#                 `&lt;div&gt;
#                      판교역 입구
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_567e20637dc94dda4978568b6e91514e = L.marker(
#                 [37.394946, 127.111104],
#                 {}
#             ).addTo(map_8ca8897fb94e2e302617c1e1c82b4a4a);
#
#
#             var icon_acf09bcdcff2dbe261d5ddc9d4059b14 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_567e20637dc94dda4978568b6e91514e.setIcon(icon_acf09bcdcff2dbe261d5ddc9d4059b14);
#
#
#         var popup_5b1d9538c61b50285dfa55e2593d2f21 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_898367e047ba880a0a241845492e35b1 = $(`&lt;div id=&quot;html_898367e047ba880a0a241845492e35b1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;판교역&lt;/div&gt;`)[0];
#                 popup_5b1d9538c61b50285dfa55e2593d2f21.setContent(html_898367e047ba880a0a241845492e35b1);
#
#
#
#         marker_567e20637dc94dda4978568b6e91514e.bindPopup(popup_5b1d9538c61b50285dfa55e2593d2f21)
#         ;
#
#
#
#
#             marker_567e20637dc94dda4978568b6e91514e.bindTooltip(
#                 `&lt;div&gt;
#                      판교역 입구
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b19b6a508d763de60d66c94eaf86a20d = L.marker(
#                 [37.394946, 127.111104],
#                 {}
#             ).addTo(map_8ca8897fb94e2e302617c1e1c82b4a4a);
#
#
#         var popup_9fe9d36bcb6f1a075e3bec96638eafe9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_09103caf4fcbd8f31f61a9a93a9b7c42 = $(`&lt;div id=&quot;html_09103caf4fcbd8f31f61a9a93a9b7c42&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;iframe width=&quot;560&quot; height=&quot;315&quot; src=&quot;https://www.youtube.com/embed/dpwTOQri42s&quot; title=&quot;YouTube video player&quot; frameborder=&quot;0&quot; allow=&quot;accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture&quot; allowfullscreen&gt;&lt;/iframe&gt;&lt;/div&gt;`)[0];
#                 popup_9fe9d36bcb6f1a075e3bec96638eafe9.setContent(html_09103caf4fcbd8f31f61a9a93a9b7c42);
#
#
#
#         marker_b19b6a508d763de60d66c94eaf86a20d.bindPopup(popup_9fe9d36bcb6f1a075e3bec96638eafe9)
#         ;
#
#
#
#
#             marker_b19b6a508d763de60d66c94eaf86a20d.bindTooltip(
#                 `&lt;div&gt;
#                      판교역 입구
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
folium.CircleMarker([latitude, longitude],
                    color='tomato',
                    radius = 50, 
                    tooltip='판교역 상권').add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8ca8897fb94e2e302617c1e1c82b4a4a {
#                     position: relative;
#                     width: 750.0px;
#                     height: 500.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8ca8897fb94e2e302617c1e1c82b4a4a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8ca8897fb94e2e302617c1e1c82b4a4a = L.map(
#                 &quot;map_8ca8897fb94e2e302617c1e1c82b4a4a&quot;,
#                 {
#                     center: [37.394946, 127.111104],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 17,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_390528d348d12aea5a88969cf4ed2ec4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8ca8897fb94e2e302617c1e1c82b4a4a);
#
#
#             var marker_677b6d714d85d2699234e815741b250e = L.marker(
#                 [37.394946, 127.111104],
#                 {}
#             ).addTo(map_8ca8897fb94e2e302617c1e1c82b4a4a);
#
#
#         var popup_a5eab5f2c933018ce77ae90ec33257e8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a4d7f24dd0edadd9cd6218a738ad164f = $(`&lt;div id=&quot;html_a4d7f24dd0edadd9cd6218a738ad164f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;판교역&lt;/div&gt;`)[0];
#                 popup_a5eab5f2c933018ce77ae90ec33257e8.setContent(html_a4d7f24dd0edadd9cd6218a738ad164f);
#
#
#
#         marker_677b6d714d85d2699234e815741b250e.bindPopup(popup_a5eab5f2c933018ce77ae90ec33257e8)
#         ;
#
#
#
#
#             marker_677b6d714d85d2699234e815741b250e.bindTooltip(
#                 `&lt;div&gt;
#                      판교역 입구
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_567e20637dc94dda4978568b6e91514e = L.marker(
#                 [37.394946, 127.111104],
#                 {}
#             ).addTo(map_8ca8897fb94e2e302617c1e1c82b4a4a);
#
#
#             var icon_acf09bcdcff2dbe261d5ddc9d4059b14 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_567e20637dc94dda4978568b6e91514e.setIcon(icon_acf09bcdcff2dbe261d5ddc9d4059b14);
#
#
#         var popup_5b1d9538c61b50285dfa55e2593d2f21 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_898367e047ba880a0a241845492e35b1 = $(`&lt;div id=&quot;html_898367e047ba880a0a241845492e35b1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;판교역&lt;/div&gt;`)[0];
#                 popup_5b1d9538c61b50285dfa55e2593d2f21.setContent(html_898367e047ba880a0a241845492e35b1);
#
#
#
#         marker_567e20637dc94dda4978568b6e91514e.bindPopup(popup_5b1d9538c61b50285dfa55e2593d2f21)
#         ;
#
#
#
#
#             marker_567e20637dc94dda4978568b6e91514e.bindTooltip(
#                 `&lt;div&gt;
#                      판교역 입구
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b19b6a508d763de60d66c94eaf86a20d = L.marker(
#                 [37.394946, 127.111104],
#                 {}
#             ).addTo(map_8ca8897fb94e2e302617c1e1c82b4a4a);
#
#
#         var popup_9fe9d36bcb6f1a075e3bec96638eafe9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_09103caf4fcbd8f31f61a9a93a9b7c42 = $(`&lt;div id=&quot;html_09103caf4fcbd8f31f61a9a93a9b7c42&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;iframe width=&quot;560&quot; height=&quot;315&quot; src=&quot;https://www.youtube.com/embed/dpwTOQri42s&quot; title=&quot;YouTube video player&quot; frameborder=&quot;0&quot; allow=&quot;accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture&quot; allowfullscreen&gt;&lt;/iframe&gt;&lt;/div&gt;`)[0];
#                 popup_9fe9d36bcb6f1a075e3bec96638eafe9.setContent(html_09103caf4fcbd8f31f61a9a93a9b7c42);
#
#
#
#         marker_b19b6a508d763de60d66c94eaf86a20d.bindPopup(popup_9fe9d36bcb6f1a075e3bec96638eafe9)
#         ;
#
#
#
#
#             marker_b19b6a508d763de60d66c94eaf86a20d.bindTooltip(
#                 `&lt;div&gt;
#                      판교역 입구
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_1d29aca044e9749bc75d45c7fe453753 = L.circleMarker(
#                 [37.394946, 127.111104],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;tomato&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: fals

# %%
import pandas as pd

# %%
df = pd.read_csv('소상공인시장진흥공단_상가(상권)정보_경기_202109.csv')
df.head(3)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\whgml\Desktop\메타버스아카데미_DS\미니프로젝트\9월_공공데이터\folium.ipynb Cell 14 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/whgml/Desktop/%EB%A9%94%ED%83%80%EB%B2%84%EC%8A%A4%EC%95%84%EC%B9%B4%EB%8D%B0%EB%AF%B8_DS/%EB%AF%B8%EB%8B%88%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8/9%EC%9B%94_%EA%B3%B5%EA%B3%B5%EB%8D%B0%EC%9D%B4%ED%84%B0/folium.ipynb#X20sZmlsZQ%3D%3D?line=0'>1</a> df = pd.read_csv('소상공인시장진흥공단_상가(상권)정보_경기_202109.csv')
#       <a href='vscode-notebook-cell:/c%3A/Users/whgml/Desktop/%EB%A9%94%ED%83%80%EB%B2%84%EC%8A%A4%EC%95%84%EC%B9%B4%EB%8D%B0%EB%AF%B8_DS/%EB%AF%B8%EB%8B%88%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8/9%EC%9B%94_%EA%B3%B5%EA%B3%B5%EB%8D%B0%EC%9D%B4%ED%84%B0/folium.ipynb#X20sZmlsZQ%3D%3D?line=1'>2</a> df.head(3)
#
# File c:\Users\whgml\miniconda3\envs\gpu\lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\whgml\miniconda3\envs\gpu\lib\site-packages\pandas\io\parsers\readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File c:\Users\whgml\miniconda3\envs\gpu\lib\site-packages\pandas\io\parsers\readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\whgml\miniconda3\envs\gpu\lib\site-packages\pandas\io\parsers\readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File c:\Users\whgml\miniconda3\envs\gpu\lib\site-packages\pandas\io\common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '소상공인시장진흥공단_상가(상권)정보_경기_202109.csv'

# %%
pd.Series(df.columns)

# %%
sub_df = df.loc[df['행정동명'].isin(['백현동', '정자동', '삼평동'])]
sub_df.head(3)

# %%
sub_df[['위도', '경도', '상호명']]

# %%
from folium.plugins import MarkerCluster


m = folium.Map(
    location=[latitude, longitude],
    zoom_start=15
)

coords = sub_df[['위도', '경도']]


marker_cluster = MarkerCluster().add_to(m)

for lat, long in zip(coords['위도'], coords['경도']):
    folium.Marker([lat, long], icon = folium.Icon(color="green")).add_to(marker_cluster)
m
